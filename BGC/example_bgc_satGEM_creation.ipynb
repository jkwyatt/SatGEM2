# %%
from bgc_satgem import create_bgc_satGEM

satGEM = create_bgc_satGEM(
    dates=("2015-01-01", "2015-01-02"),
    lon_min=120,
    lon_max=140,
    lat_min=-60,
    lat_max=-50,
    gem_path="https://zenodo.org/records/17824264/files/gem_seasonal_all.nc?download=1",
    lut_dir="/g/data/jk72/jw2777/BGC_GLOBAL/DATA/ADT_DYNM/",
    vars_to_keep=["CT", "SA"]  # optional
)
# Out:
# C:\Users\jkwyatt\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\jkwyatt\Anaconda3\lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Downloading https://zenodo.org/records/17824264/files/gem_seasonal_all.nc?download=1 → C:\Users\jkwyatt\AppData\Local\Temp\gem_seasonal_all.nc

# %%
satGEM_field
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (time: 2, latitude: 40, longitude: 1440, pressure: 400)
# Coordinates:
#     month      (time) int64 16B 1 1
#   * pressure   (pressure) float32 2kB 2.5 7.5 12.5 ... 1.992e+03 1.998e+03
#   * time       (time) datetime64[ns] 16B 2020-01-30 2020-01-31
#   * latitude   (latitude) float32 160B -59.88 -59.62 -59.38 ... -50.38 -50.12
#   * longitude  (longitude) float32 6kB -179.9 -179.6 -179.4 ... 179.6 179.9
# Data variables:
#     CT         (time, latitude, longitude, pressure) float64 369MB 5.722 ... ...
#     SA         (time, latitude, longitude, pressure) float64 369MB 34.08 ... ...
#     sigma      (time, latitude, longitude, pressure) float64 369MB 26.74 ... ...
#     doxy       (time, latitude, longitude, pressure) float64 369MB 309.7 ... ...
#     nitrate    (time, latitude, longitude, pressure) float64 369MB 0.0 ... 32.01

# %%
satGEM_field.CT[0,:,:,100].plot()
