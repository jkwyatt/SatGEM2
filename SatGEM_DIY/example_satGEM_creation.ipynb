# %%
from SatGEM_DIY.satgem_build import build_satGEM_fields

# %%
# Date range
ts_range, gamma_range = build_satGEM_fields(
    dates=("2020-01-01", "2020-01-02"),
    lon_min=140, lon_max=150,
    lat_min=-60, lat_max=-50,
    csv_path='SatGEM_DIY/saved_adt_rel.csv',
    static_ts_dir='SatGEM_DIY/ts_gem_fields',
    static_gamma_dir='SatGEM_DIY/gamma_gem_fields',
    dataset_id="c3s_obs-sl_glo_phy-ssh_my_twosat-l4-duacs-0.25deg_P1D",
)
# Out:
# INFO - 2025-11-27T23:41:05Z - Selected dataset version: "202411"
# INFO - 2025-11-27T23:41:05Z - Selected dataset part: "default"
# Processing longitudes: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:57<00:00,  1.43s/it]

# %%
ts_range
# Out:
# <xarray.Dataset> Size: 86MB
# Dimensions:    (time: 3, latitude: 40, longitude: 40, pressure: 558)
# Coordinates:
#   * pressure   (pressure) int64 4kB 0 10 20 30 40 ... 5530 5540 5550 5560 5570
#   * latitude   (latitude) float32 160B -59.88 -59.62 -59.38 ... -50.38 -50.12
#   * time       (time) datetime64[ns] 24B 2020-01-01 2020-01-02 2020-01-03
#   * longitude  (longitude) float32 160B 140.1 140.4 140.6 ... 149.4 149.6 149.9
#     ssh        (time, latitude, longitude) float64 38kB -0.8598 ... 0.4322
# Data variables:
#     temp       (time, latitude, longitude, pressure) float64 21MB 1.724 ... nan
#     temp_mask  (time, latitude, longitude, pressure) float64 21MB 1.768 ... nan
#     sal        (time, latitude, longitude, pressure) float64 21MB 33.99 ... nan
#     sal_mask   (time, latitude, longitude, pressure) float64 21MB 33.98 ... nan

# %%
gamma_range[0,:,:,10].plot()
